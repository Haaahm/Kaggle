# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# 머신러닝
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
print(train.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
print('train data shape: ', train.shape)
print('test data shape: ', test.shape)
print()
print('----------[train infomation]----------')
print(train.info())
print()
print('----------[test infomation]----------')
print(test.info())
# Out:
# train data shape:  (891, 12)
# test data shape:  (418, 11)
#
# ----------[train infomation]----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# ----------[test infomation]----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
# None

# %%
# 파이차트 함수 생성
def pie_chart(feature):
    feature_ratio = train[feature].value_counts(sort=False)
    feature_size = feature_ratio.size
    feature_index = feature_ratio.index
    survived = train[train['Survived'] == 1][feature].value_counts()
    dead = train[train['Survived'] == 0][feature].value_counts()


    plt.plot(aspect='auto')
    plt.pie(feature_ratio, labels=feature_index, autopct='%1.1f%%')
    plt.title(feature + '\'s ratio in total')
    plt.show()

    for i, index in enumerate(feature_index):
       plt.subplot(1, feature_size + 1, i + 1, aspect='equal')
       plt.pie([survived[index], dead[index]], labels=['Survivied', 'Dead'], autopct='%1.1f%%')
       plt.title(str(index) + '\'s ratio')

    plt.show()

# %%
pie_chart('Sex') # 성별 파이차트

# %%
# Class 좌석등급별
pie_chart('Pclass')

# %%
# 승선한 장소
pie_chart('Embarked')

# %%
# 동반한 형제자매 생존
sbs=train[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
print(sbs)
sbs.plot("SibSp",kind="bar").set_xlabel("SibSp")
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000
# Text(0.5, 0, 'SibSp')

# %%
# 동반한 부모자녀 생존
pcs=train[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
print(pcs)
pcs.plot("Parch",kind="bar").set_xlabel("Parch")
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000
# Text(0.5, 0, 'Parch')

# %%
# 생존자 나이
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
grid = sns.FacetGrid(train, col='Survived', row='Pclass', height=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();

# %%
pd.crosstab([train.Sex,train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a249b_row0_col0, #T_a249b_row0_col1, #T_a249b_row0_col3, #T_a249b_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a249b_row0_col2, #T_a249b_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_a249b_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_a249b_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_a249b_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_a249b_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_a249b_row2_col1, #T_a249b_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_a249b_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_a249b_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_a249b_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_a249b_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_a249b_row4_col0, #T_a249b_row4_col1, #T_a249b_row4_col2, #T_a249b_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a249b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_a249b_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_a249b_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_a249b_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_a249b_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a249b_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_a249b_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_a249b_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_a249b_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_a249b_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_a249b_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_a249b_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_a249b_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_a249b_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_a249b_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_a249b_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_a249b_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_a249b_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_a249b_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_a249b_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_a249b_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_a249b_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_a249b_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_a249b_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_a249b_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_a249b_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_a249b_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_a249b_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_a249b_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_a249b_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_a249b_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_a249b_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_a249b_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', data=train, kind='point')

# %%
# 바이올린 플롯으로 객실과 나이에 대한 생존자 비율, 성별과 나이에 대한 생존자 비율을 살펴본다.
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age VS Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax[1])
ax[1].set_title('Sex and Age VS Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
grid = sns.FacetGrid(train, row='Embarked', col='Survived', height=4, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend()

# %%
S = train[train['Embarked'] == 'S']['Pclass'].value_counts()
C = train[train['Embarked'] == 'C']['Pclass'].value_counts()
Q = train[train['Embarked'] == 'Q']['Pclass'].value_counts()
df = pd.DataFrame([S, C, Q])
df.index = ['S', 'C', 'Q']
df.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
sns.heatmap(train.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
print("Before", train.shape, test.shape)

train= train.drop(['Ticket', 'Cabin'], axis=1)
test= test.drop(['Ticket', 'Cabin'], axis=1)
combine = [train, test]

print("After", train.shape, test.shape)
# Out:
# Before (891, 12) (418, 11)
# After (891, 10) (418, 9)

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

print(pd.crosstab(train['Title'], train['Sex']))
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

print(train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean())
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

print(train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %%
train = train.drop(['Name', 'PassengerId'], axis=1)
test = test.drop(['Name'], axis=1)
combine = [train, test]
#test데이터셋에는 PassegnerId변수가 없습니다.

print(train.shape, test.shape)
# Out:
# (891, 9) (418, 9)

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

print(train.head())
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Title         0
# dtype: int64

# %%
train.median()
# Out:
# Survived     0.0000
# Pclass       3.0000
# Sex          0.0000
# Age         28.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# Title        1.0000
# dtype: float64

# %%
train["Age"].fillna(train.groupby("Sex")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("Sex")["Age"].transform("median"), inplace=True)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
#  8   Title     891 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 62.8+ KB

# %%
freq_port = train.Embarked.dropna().mode()[0] # "S"
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# %%
train['AgeBand'] = pd.cut(train['Age'], 5)
#임의로 5개의 그룹을 지정합니다.
print(train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True))
# Out:
#             AgeBand  Survived
# 0    (0.34, 16.336]  0.550000
# 1  (16.336, 32.252]  0.344168
# 2  (32.252, 48.168]  0.404255
# 3  (48.168, 64.084]  0.434783
# 4    (64.084, 80.0]  0.090909

# %%
for dataset in combine:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age']
train = train.drop(['AgeBand'], axis=1)
combine = [train, test]
print(train.head())
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked  Title
# 0         0       3    0  1.0      1      0   7.2500         0      1
# 1         1       1    1  2.0      1      0  71.2833         1      3
# 2         1       3    1  1.0      0      0   7.9250         0      2
# 3         1       1    1  2.0      1      0  53.1000         0      3
# 4         0       3    0  2.0      0      0   8.0500         0      1

# %%
for dataset in combine:
    dataset['Age*Class'] = dataset.Age * dataset.Pclass

print(train.loc[:, ['Age*Class', 'Age', 'Pclass']].head(3))
# Out:
#    Age*Class  Age  Pclass
# 0        3.0  1.0       3
# 1        2.0  2.0       1
# 2        3.0  1.0       3

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
                                                               #자기 자신을 포함시킵니다.
print(train[['FamilySize', 'Survived']].groupby(['FamilySize'],
                as_index=False).mean().sort_values(by='Survived', ascending=False))
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

print(train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean())
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
train = train.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
test = test.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
combine = [train, test]

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4)
print(train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True))
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
test['Fare'].fillna(test['Fare'].dropna().median(), inplace=True)

# %%
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train = train.drop(['FareBand'], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  Age*Class  IsAlone
# 0         0       3    0  1.0     0         0      1        3.0        0
# 1         1       1    1  2.0     3         1      3        2.0        0
# 2         1       3    1  1.0     1         0      2        3.0        1
# 3         1       1    1  2.0     3         0      3        2.0        0
# 4         0       3    0  2.0     1         0      1        6.0        1

# %%
train.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age          0
# Fare         0
# Embarked     0
# Title        0
# Age*Class    0
# IsAlone      0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# Title          0
# Age*Class      0
# IsAlone        0
# dtype: int64

# %%
# One-hot-encoding for categorical variables
train = pd.get_dummies(train)
test = pd.get_dummies(test)

train_label = train['Survived']
train_data = train.drop('Survived', axis=1)
test_data = test.drop("PassengerId", axis=1).copy()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

from sklearn.utils import shuffle

# %%
train_data, train_label = shuffle(train_data, train_label, random_state = 5)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 8), (891,))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

# %%
# kNN 점수 확인
round(np.mean(score)*100, 2)
# Out:
# 81.26

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

# %%
# decision tree 점수 확인
round(np.mean(score)*100, 2)
# Out:
# 81.15

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

# %%
# Random Forest 점수 확인
round(np.mean(score)*100, 2)
# Out:
# 82.27

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

# %%
# Naive Bayes 점수 확인
round(np.mean(score)*100, 2)
# Out:
# 69.13

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

# %%
round(np.mean(score)*100, 2)
# Out:
# 78.23

# %%
from xgboost import XGBClassifier

clf = XGBClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)

round(np.mean(score)*100,2)
# Out:
# 82.05

# %%
# clf = SVC()
clf = XGBClassifier(n_estimators=13)
# clf = RandomForestClassifier(n_estimators=13)
clf.fit(train_data, target)
test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
test_ori = pd.read_csv('/content/test.csv')

# %%
제출값 = pd.DataFrame({"PassengerId": test["PassengerId"],"Survived": prediction})
제출값.to_csv('titanic_ver_11.csv', index=False)

# %%
제출값
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
